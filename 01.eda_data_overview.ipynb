# %%
import pandas as pd
import numpy as np
import glob
import pyarrow

# %%
print("pandas:", pd.__version__)
print("pyarrow:", pyarrow.__version__)
# Out:
# pandas: 2.1.4
# pyarrow: 14.0.2

# %%
df1=pd.read_parquet('part1.parquet', engine='pyarrow')

# %%
df1.sample(5)
# Out:
#                                 event_id     event_name      event_timestamp  \
# 1   d97bcb86-5cd2-4ef2-a528-e86023bc5087  appBackground  2025-03-11 14:10:34
# 8   6fd253b5-7c72-4a67-8064-3baf0d6cb74d       appFocus  2025-03-11 14:12:13
# 15  f2c2e817-fca4-403c-bb46-884a8bc0ddc1  transferMoney  2025-03-11 14:11:08
# 6   9bea3bcc-9c80-4a61-a845-d5b840fb022c   tokenCashout  2025-03-11 14:11:04
# 10  2b0689fe-58a6-4b66-9b25-bbc338c508a9      firstOpen  2025-03-11 14:10:19
#
#                                      event_properties   event_receive_time  \
# 1   [(onAppBackground, True), (timeStamp, 17417022...  2025-02-11 15:10:57
# 8    [(onAppFocus, True), (timeStamp, 1741702333738)]  2025-02-11 15:12:20
# 15  [(moneyId, cash_map01), (totalMoneyInStack, 0)...  2025-02-11 15:11:18
# 6   [(numberOfDay, 0), (orangeTokenCount, 0), (mon...  2025-02-11 15:11:14
# 10                                                 []  2025-02-11 15:10:23
#
#                                  user_id  \
# 1   92aabe08-e23e-4f74-96ff-b77b7adaadfb
# 8   92aabe08-e23e-4f74-96ff-b77b7adaadfb
# 15  92aabe08-e23e-4f74-96ff-b77b7adaadfb
# 6   92aabe08-e23e-4f74-96ff-b77b7adaadfb
# 10  92aabe08-e23e-4f74-96ff-b77b7adaadfb
#
#                          user_session_id user_session_issued_at  \
# 1   0513d7cf-c5f1-4f3d-8048-5d440f32690b    2025-02-11 15:04:20
# 8   0513d7cf-c5f1-4f3d-8048-5d440f32690b    2025-02-11 15:04:20
# 15  0513d7cf-c5f1-4f3d-8048-5d440f32690b    2025-02-11 15:04:20
# 6   0513d7cf-c5f1-4f3d-8048-5d440f32690b    2025-02-11 15:04:20
# 10  0513d7cf-c5f1-4f3d-8048-5d440f32690b    2025-02-11 15:04:20
#
#     user_session_count                             user_properties_custom  \
# 1                    1  [(noAdsOwned, False), (robotOwned, False), (fb...
# 8                    1  [(fbInstallationId, c9ZUR267RM6sNy9RovUUh6), (...
# 15                   1  [(adjustId, 02bfe852503880da4b13848aa21b77fa),...
# 6                    1  [(adjustId, 02bfe852503880da4b13848aa21b77fa),...
# 10                   1  [(fbInstallationId, c9ZUR267RM6sNy9RovUUh6), (...
#
#    client_platform country_code         processing_time
# 1          Android           CA 2025-03-11 14:04:30.899
# 8          Android           CA 2025-03-11 14:04:30.899
# 15         Android           CA 2025-03-11 14:04:30.899
# 6          Android           CA 2025-03-11 14:04:30.899
# 10         Android           CA 2025-03-11 14:04:30.899

# %%
print(df1['event_timestamp'].min())
print(df1['event_timestamp'].max())
print(df1['processing_time'].min())
print(df1['processing_time'].max())
# Out:
# 2025-03-11 14:10:19
# 2025-03-11 14:12:13
# 2025-03-11 14:04:30.899000
# 2025-03-11 14:04:30.899000

# %%
df2=pd.read_parquet('part2.parquet', engine='pyarrow')

# %%
df2.head()
# Out:
#                                event_id         event_name  \
# 0  df592792-841a-4376-8a00-cca14479cd43         gameOpened
# 1  3d56fe33-f02f-43d9-812e-18d9689bad12      transferMoney
# 2  c5278e8a-bf0d-4425-b9bd-a508e68b4a14       deviceRepair
# 3  7d24539d-a7d8-408f-b2e7-c6162ac58de1           endOfDay
# 4  3f73c490-0900-4bf2-8d31-cddbc29f4570  badCustomerResult
#
#        event_timestamp                                   event_properties  \
# 0  2025-03-03 08:19:20                                                 []
# 1  2025-03-05 20:25:38  [(moneyId, cash_map04), (totalMoneyInStack, 0)...
# 2  2025-03-05 20:25:39  [(deviceRepairTimeStamp, 1741206339), (moneyIn...
# 3  2025-03-05 20:25:41  [(happyCustomer, 56), (sadCustomer, 23), (mapI...
# 4  2025-03-05 20:25:42                                 [(slapped, False)]
#
#     event_receive_time                               user_id  \
# 0  2025-02-10 08:19:11  6c6028eb-04f9-421e-b957-e62729be0d6f
# 1  2025-03-05 20:25:37  590171b3-6962-4282-b175-996715e41c1a
# 2  2025-03-05 20:25:39  fb782ccc-1e72-49b7-8eed-847de77311cb
# 3  2025-03-05 20:25:41  c104bad7-5f43-4bcf-887e-d0530963b22a
# 4  2025-03-05 20:25:42  9db2ae53-3cde-4139-a0c7-7478e82029b2
#
#                         user_session_id user_session_issued_at  \
# 0  7fcaec19-7ccb-4e84-a368-a4f974fdf96a    2025-02-10 08:18:58
# 1  2c1a3ff3-4c3a-4864-8a7d-3517989c8106    2025-03-05 20:23:45
# 2  0c06090b-a7a3-4aed-b0e1-a53ac09f15a6    2025-03-05 20:16:07
# 3  2387f936-1fe5-426a-a9d4-3303c4fae934    2025-03-05 20:00:07
# 4  ebf81b0e-b582-4578-9547-78985134661a    2025-03-05 20:20:20
#
#    user_session_count                             user_properties_custom  \
# 0                   5  [(appVersion, 0.21.13), (currentMap, 2), (noAd...
# 1                 156  [(currentMap, 4), (noAdsOwned, False), (robotO...
# 2                   9  [(fbInstallationId, elzTU-8uTZCmB8thUrlEjS), (...
# 3                   2  [(adjustId, 7d34954bf47df1228daa64d28137c61e),...
# 4                   6  [(adjustId, 4f38b0febabb37e016325062352a719d),...
#
#   client_platform country_code         processing_time
# 0         Android           SA 2025-03-11 14:06:53.773
# 1         Android           GB 2025-03-11 14:08:12.337
# 2         Android           US 2025-03-11 14:08:12.337
# 3         Android           FR 2025-03-11 14:08:12.337
# 4         Android           IT 2025-03-11 14:08:12.337

# %%
print(df2['event_timestamp'].min())
print(df2['event_timestamp'].max())
print(df2['processing_time'].min())
print(df2['processing_time'].max())
# Out:
# 2025-03-03 08:19:20
# 2025-03-05 21:27:14
# 2025-03-11 14:06:53.773000
# 2025-03-11 14:08:12.337000

# %%
df3=pd.read_parquet('part3.parquet', engine='pyarrow')

# %%
df3.head()
# Out:
#                                event_id             event_name  \
# 0  28a7cf05-ecec-4678-8221-3b9f138376aa           itemsGranted
# 1  bfe144f5-ef87-4924-a136-31b70e49bd97  interstitialLifecycle
# 2  d4693af5-8c55-4e3a-896d-d3b23080dd4f   playerAbilityClaimed
# 3  f3d05df3-191b-4a19-b165-87994655aff3           lostCustomer
# 4  fb175e5b-73fe-41f6-90a8-b99bd6d87094  interstitialLifecycle
#
#        event_timestamp                                   event_properties  \
# 0  2025-03-01 13:08:37       [(item_id, zombie), (source, items_granted)]
# 1  2025-03-01 13:08:37  [(errorInfo, no error), (id, 37de33a6651838c0)...
# 2  2025-03-01 13:08:36  [(playerLevel, 4), (centerLevel, 4), (mapId, m...
# 3  2025-03-01 13:08:40  [(moneyId, cash_map05), (numberOfBrokenDevices...
# 4  2025-03-01 13:08:40  [(id, 45f7c5074e14c2cb), (state, AdLoaded), (e...
#
#     event_receive_time                               user_id  \
# 0  2025-03-01 13:08:37  a8e47d1c-918c-4483-99b8-c01cf34db136
# 1  2025-03-01 13:08:38  43d980e6-387a-4ac5-b46b-e31ad608504d
# 2  2025-03-01 13:08:38  453dd329-4bb5-4364-b426-c451c670c1ce
# 3  2025-03-01 13:08:40  4493cad5-2613-458c-b947-99bf5cb0639d
# 4  2025-03-01 13:08:40  2f1068b8-f5d9-44d7-8d99-4148e959fe24
#
#                         user_session_id user_session_issued_at  \
# 0                                          2025-03-01 13:08:37
# 1  d6d363d5-6dd0-4bdd-9cb0-9f79528d26b7    2025-03-01 13:03:12
# 2  f282f537-a18d-493a-bdd8-cb4d16d4eb4e    2025-03-01 12:58:09
# 3  53bdf05c-d778-469e-a391-94ad036d1626    2025-03-01 12:47:33
# 4  f9d11e71-ff30-4097-bed3-26a2a761a07f    2025-03-01 13:04:02
#
#    user_session_count                             user_properties_custom  \
# 0                   1  [(noAdsOwned, False), (robotOwned, False), (fb...
# 1                   2  [(adjustId, 07a67216f82f008ae7627b4dedc3c870),...
# 2                   7  [(adjustId, 7d8b6075e095b196fc2b4615da2f6a59),...
# 3                  40  [(noAdsOwned, True), (robotOwned, False), (fbI...
# 4                  84  [(adjustId, d50e1771f3b7ca737ddc93ff34561745),...
#
#   client_platform country_code         processing_time
# 0         Android           US 2025-03-11 14:08:12.337
# 1    IPhonePlayer           NO 2025-03-11 14:08:12.337
# 2         Android           ES 2025-03-11 14:08:12.337
# 3         Android           FR 2025-03-11 14:08:12.337
# 4         Android           US 2025-03-11 14:08:12.337

# %%
print(df3['event_timestamp'].min())
print(df3['event_timestamp'].max())
print(df3['processing_time'].min())
print(df3['processing_time'].max())
# Out:
# 2025-03-01 10:19:35
# 2025-03-05 22:51:16
# 2025-03-11 14:08:12.337000
# 2025-03-11 14:08:12.337000

# %%
df4 = pd.read_parquet('part4.parquet', engine='pyarrow')

# %%
df4.head()
# Out:
#                                event_id             event_name  \
# 0  4bd93a2e-19dd-4ffa-a0d8-b096a6347f0e  interstitialLifecycle
# 1  21d47e89-a154-42c9-8b87-1ce1d7041cd9  interstitialLifecycle
# 2  57b89080-0d18-47a8-b174-b21ff791d623            adsReturned
# 3  6c1b8776-1f26-4ecb-88ea-5f61b1119d22           adImpression
# 4  3929e9f9-f7df-4a3f-8c49-fe802c2479f4           lostCustomer
#
#        event_timestamp                                   event_properties  \
# 0  2025-03-02 19:23:36  [(id, 37de33a6651838c0), (state, AdClicked), (...
# 1  2025-03-02 19:23:37  [(id, 45f7c5074e14c2cb), (state, AdDisplayed),...
# 2  2025-03-02 19:23:38                       [(timeStamp, 1740943418329)]
# 3  2025-03-02 19:23:39  [(adPlatform, Applovin), (adUnitName, 37de33a6...
# 4  2025-03-02 19:23:39  [(numberOfBrokenDevices, 9), (numberOfUnlockDe...
#
#     event_receive_time                               user_id  \
# 0  2025-03-02 19:23:36  d01ef176-cac3-4d5e-99a3-959abc4dae94
# 1  2025-03-02 19:23:37  ea74c0ad-9526-4d63-bde7-6f0e6f5c0808
# 2  2025-03-02 19:23:38  ea74c0ad-9526-4d63-bde7-6f0e6f5c0808
# 3  2025-03-02 19:23:39  c1dbcb95-f100-4eaa-86cb-da42607871e7
# 4  2025-03-02 19:23:40  d6ec90bb-b5fa-46ac-97d4-9beeed62747e
#
#                         user_session_id user_session_issued_at  \
# 0  ed31e82f-b418-4b04-b2b4-5e9ddb0fcdc7    2025-03-02 19:12:47
# 1  fab7dcb3-9f82-4840-a598-928bbb2bd481    2025-03-02 18:14:39
# 2  fab7dcb3-9f82-4840-a598-928bbb2bd481    2025-03-02 18:14:39
# 3  3fa92680-99e3-43b0-a4ff-2c0c89c980ca    2025-03-02 19:21:32
# 4  b276fb10-2019-40c8-8f1c-8c57bae8afce    2025-03-02 14:28:05
#
#    user_session_count                             user_properties_custom  \
# 0                   5  [(adjustId, e22625bbecf92d026241e6faf934aa50),...
# 1                   2  [(adjustId, c9706ccef5e6696ae8d26a5b9ce5eea8),...
# 2                   2  [(robotOwned, False), (fbInstallationId, dOICY...
# 3                   4  [(robotOwned, False), (fbInstallationId, czG8h...
# 4                  51  [(fbInstallationId, f5LHlCxRRGaadWaWKZQynv), (...
#
#   client_platform country_code         processing_time
# 0    IPhonePlayer           IT 2025-03-11 14:08:12.337
# 1         Android           NL 2025-03-11 14:08:12.337
# 2         Android           NL 2025-03-11 14:08:12.337
# 3    IPhonePlayer           GB 2025-03-11 14:08:12.337
# 4         Android           CH 2025-03-11 14:08:12.337

# %%
print(df4['event_timestamp'].min())
print(df4['event_timestamp'].max())
print(df4['processing_time'].min())
print(df4['processing_time'].max())
# Out:
# 2025-03-01 14:59:46
# 2025-03-06 04:17:38
# 2025-03-11 14:08:12.337000
# 2025-03-11 14:08:12.337000

# %%
df = pd.concat([df1, df2, df3, df4])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2811413 entries, 0 to 1321598
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   event_id                object
#  1   event_name              object
#  2   event_timestamp         object
#  3   event_properties        object
#  4   event_receive_time      object
#  5   user_id                 object
#  6   user_session_id         object
#  7   user_session_issued_at  object
#  8   user_session_count      int64
#  9   user_properties_custom  object
#  10  client_platform         object
#  11  country_code            object
#  12  processing_time         datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 300.3+ MB

# %%
df['event_timestamp'] = pd.to_datetime(df['event_timestamp'])
df['user_session_issued_at'] = pd.to_datetime(df['user_session_issued_at'])
df['event_receive_time'] = pd.to_datetime(df['event_receive_time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2811413 entries, 0 to 1321598
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   event_id                object
#  1   event_name              object
#  2   event_timestamp         datetime64[ns]
#  3   event_properties        object
#  4   event_receive_time      datetime64[ns]
#  5   user_id                 object
#  6   user_session_id         object
#  7   user_session_issued_at  datetime64[ns]
#  8   user_session_count      int64
#  9   user_properties_custom  object
#  10  client_platform         object
#  11  country_code            object
#  12  processing_time         datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(8)
# memory usage: 300.3+ MB

# %%
df_s = df.sample(50000)
df_s.head()
# Out:
#                                     event_id             event_name  \
# 58579   485addd6-bff0-4750-a98d-76e3ade6354e             gameOpened
# 940055  6d922a93-74b6-471d-822d-c5e8974a12e0           lostCustomer
# 634889  3a78b54a-8655-4977-bb6f-915fb09d0fb8        currencyGranted
# 49758   8568ddb2-80f9-4be8-a8ee-7e15e64cc281  interstitialLifecycle
# 698316  e1359e11-bda5-44fc-b5d7-630121eeb443     upgradeProgression
#
#            event_timestamp                                   event_properties  \
# 58579  2025-03-02 14:27:31                                                 []
# 940055 2025-03-05 16:34:48  [(moneyId, cash_map05), (numberOfBrokenDevices...
# 634889 2025-03-04 22:37:59  [(source, economy_granted), (currency_id, cash...
# 49758  2025-03-05 21:15:06  [(id, 45f7c5074e14c2cb), (state, AdLoaded), (e...
# 698316 2025-03-02 18:41:29  [(progressCount, 126), (totalProgressCount, 17...
#
#         event_receive_time                               user_id  \
# 58579  2025-03-02 14:27:32  0953cde5-8633-42dd-b0b9-2a7b01578659
# 940055 2025-03-05 16:34:48  1d280207-7d6a-4480-88dd-7ea7fc2f7814
# 634889 2025-03-04 22:37:59  1673d55a-c6bc-4726-bd61-085bc20d6b3e
# 49758  2025-03-05 21:15:06  0d2747ff-4469-4fdf-8286-0572e72f0e10
# 698316 2025-03-02 18:41:28  eb438e8d-e283-46cd-b652-75f95e281cfb
#
#                              user_session_id user_session_issued_at  \
# 58579   d8a81145-26bb-4e86-aedb-96ecf01d6c7a    2025-03-02 14:27:25
# 940055  93628ca4-72c9-4fe5-8b3f-256257b94e07    2025-03-05 15:39:42
# 634889                                          2025-03-04 22:37:59
# 49758   7674e8c2-56e3-4f08-907c-5a9009a522e8    2025-03-05 19:52:42
# 698316  094da912-1caf-4837-acc6-cf63eb0598a3    2025-03-02 13:42:50
#
#         user_session_count                             user_properties_custom  \
# 58579                    3  [(appVersion, 0.21.20), (currentMap, 1), (noAd...
# 940055                   6  [(adjustId, d002f20ab5edd57ddbfa9b8960a7290a),...
# 634889                  56  [(noAdsOwned, False), (robotOwned, False), (fb...
# 49758                   36  [(currentMap, 2), (noAdsOwned, False), (robotO...
# 698316                   1  [(currentMap, 2), (noAdsOwned, False), (robotO...
#
#        client_platform country_code         processing_time
# 58579          Android           JP 2025-03-11 14:08:12.337
# 940055    IPhonePlayer           KW 2025-03-11 14:08:12.337
# 634889         Android           US 2025-03-11 14:08:12.337
# 49758          Android           NO 2025-03-11 14:08:12.337
# 698316         Android           DE 2025-03-11 14:08:12.337

# %%
df_s['user_id'].nunique()
# Out:
# 5394

# %%
df_s['event_name'].value_counts()
# Out:
# event_name
# tokenCashout              6990
# lostCustomer              4807
# interstitialLifecycle     3504
# rvLifecycle               3085
# appBackground             3007
# transferMoney             2804
# appFocus                  2660
# deviceBroken              2291
# deviceRepair              2237
# achievementUpdated        2042
# badCustomerResult         1594
# upgradeProgression        1394
# badCustomerEntered        1388
# deviceUpgrade             1355
# adImpression              1353
# adsStart                  1321
# currencyGranted           1283
# adsReturned               1194
# currencySpent             1153
# unlockProgression          714
# endOfNight                 635
# endOfDay                   628
# deviceUnlocked             620
# offerClaim                 262
# buttonClick                222
# boosterClaimed             221
# _sessionStart              179
# itemsGranted               175
# gameOpened                 169
# skinOpened                 132
# playerAbilityClaimed       119
# achievementClaimed          95
# zoneUnlocked                85
# skinActivated               56
# helperUnlocked              49
# gamerRoadClaimed            46
# firstOpen                   35
# _identityCreate             31
# gameClosed                  15
# screenViewed                13
# musicOnOff                  12
# hapticOnOff                 11
# soundOnOff                   6
# inAppPurchase                3
# robot                        2
# notificationPermission       1
# energyModifierGranted        1
# noAds24HoursOffer            1
# Name: count, dtype: int64

# %%
print(df_s['event_timestamp'].min())
print(df_s['event_timestamp'].max())
# Out:
# 2025-03-01 10:24:25
# 2025-03-05 23:27:03

# %%
df['event_name'].nunique()
# Out:
# 62

# %%
df['event_name'].unique()
# Out:
# array(['appBackground', 'appFocus', 'tokenCashout', 'gameOpened',
#        'firstOpen', 'transferMoney', 'unlockProgression',
#        'deviceUnlocked', 'deviceRepair', 'endOfDay', 'badCustomerResult',
#        'adsReturned', 'achievementUpdated', 'buttonClick', 'lostCustomer',
#        'adImpression', 'badCustomerEntered', 'currencyGranted',
#        'rvLifecycle', 'interstitialLifecycle', 'deviceBroken',
#        'currencySpent', 'offerClaim', 'upgradeProgression', 'adsStart',
#        'deviceUpgrade', 'endOfNight', 'boosterClaimed', 'gameClosed',
#        'gamerRoadClaimed', 'achievementClaimed', 'zoneUnlocked',
#        'itemsGranted', 'playerAbilityClaimed', 'skinOpened',
#        '_sessionStart', '_identityCreate', 'musicOnOff', 'hapticOnOff',
#        'soundOnOff', 'skinActivated', 'helperUnlocked',
#        'purchaseCompleted', 'starterPack', 'screenViewed', 'gem2',
#        'inAppPurchase', 'specialPack', 'robot', 'gamerRoadPremium',
#        'noAds24HoursOffer', 'energyModifierGranted', 'gem1', 'robot3Days',
#        'superStarterPack', 'gem6', 'gem4', 'standardPack', 'noAds24Hours',
#        'notificationPermission', 'gem3', 'noAds'], dtype=object)

# %%
# raw_data
# df.to_csv("D:/game_data/user_log.csv", index=False, encoding="utf-8-sig")
